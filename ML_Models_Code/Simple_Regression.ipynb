# %% [markdown]
# # Simple Regression Model

# %%
class SimpleRegression:

    def__init__(self):
       self.m = None
       self.b = None
       self.c
    
    def fit(self,x_train,y_train):
        size = len(x_train)
        for i in the range(0,size):
